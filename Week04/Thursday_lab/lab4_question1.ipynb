# %% [markdown]
# Question 1: UNIFORM
#
# 1. Set up a grid of  equally spaced values between 0 and 1, {1/K, 2/K, ..., K/K}.
# 2. Draw a point from the grid at random with equal probability.
# 3. For a very small , repeat the above process n = 5_000 times, and plot the ECDF of the draws.
# 4. What distribution does this approach as you increase?
#
# ANSWER: As K increases, the distribution approaches a uniform distribution.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#1
n = 5000
k = 50

values = np.arange(1, k+1) / k

#2
draws = np.random.choice(values, size=n, replace=True)

#3
sorted_draws = np.sort(draws)
ecdf_y = np.arange(1, n + 1) / n

# %%
#plot
plt.plot(x, y)

plt.xlabel("K")
plt.ylabel("ECDF")

plt.title("ECDF for Draws")

plt.xlim(0, 1)
plt.ylim(0, 1)
plt.grid(True, alpha=0.3)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
